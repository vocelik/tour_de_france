# %%
from IPython.display import display_html
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import pandas as pd
import json
import re

# %%
class Scraper:
    
    def __init__(self):
        
        self.name = "Tour de France"
        self.years = range(1903,2021)
        self.stages = range(1,25)
        self.df_stages = []
        self.hdr = {'User-Agent': 'Mozilla/5.0'}
        self.dictionariy = {ord('ñ'): 'n', ord('ü'): 'u', ord('é'): 'e',
                            ord('í'): 'i', ord('Á'): 'A', ord('î'): 'i',
                            ord('ū'): 'u', ord('ä'): 'a', ord('è'): 'e',
                            ord('ø'): 'o', ord('æ'): 'ae', ord('š'): 's',
                            ord('ā'): 'a', ord('á'): 'a', ord('ó'): 'o',
                            ord('č'): 'c', ord('ç'): 'c', ord('ö'): 'o',
                            ord('Ó'): 'O', ord('Í'): 'I', ord('ż'): 'z',
                            ord('ï'): 'i', ord('ô'): 'o', ord('ý'): 'y',
                            ord('ć'): 'c', ord('Š'): 'S', ord('ò'): 'o',
                            ord('ë'): 'e', ord('ß'): 'ss', ord('ú'): 'u',
                            ord('ș'): 's', ord('ž'): 'z', ord('ł'): 'l',
                            ord('Đ'): 'D', ord('ś'): 's', ord('ě'): 'e',
                            ord('ř'): 'r', ord('É'): 'E', ord('ń'): 'n',
                            ord('ņ'): 'n', ord('Ł'): 'L', ord('Å'): 'A',
                            ord('ã'): 'a'}
        self.riders = []
        self.df_riders = []
        self.df_stage_types = []
    
    def scrape(self):
        
        # loop over the years
        for year in self.years:
            
            # find the site
            site = "https://www.procyclingstats.com/race/tour-de-france/" + str(year)
            # request access
            target = Request(site, headers = self.hdr)
            # open the page
            target_page = urlopen(target)
            # create soup object
            soup = BeautifulSoup(target_page)
            
            # check if page exists else continue
            if soup.find_all("div", {"class": "confirmation red notfound"}):
                print(site + " not found")
                continue
            else:
                # loop over stages
                for stage in self.stages:
                    target_site = site + "/stage-" + str(stage)
                    print(target_site)
                    target = Request(target_site, headers = self.hdr)
                    target_page = urlopen(target)
                    soup = BeautifulSoup(target_page)
            
                    if soup.find_all("div", {"class": "confirmation red notfound"}):
                        print(target_site + " not found")
                        break
                    else:
                        # find the basic results
                        a = soup.find_all("table", {"class":"basic results"})
                        
                        # convert using read_html
                        for table in a:
                            df_html = pd.read_html(str(table))
                            df = pd.concat(df_html)
                            df['Year'] = year
                            df['Stage'] = stage
                            self.df_stages.append(df)
        self.concat_df()
        #self.finalize_df()
    
    def finalize_df(self):# run the rest of the program and save output
        
        self.clean_riders()
        self.scrape_riders()
        self.stages_save_csv()
        self.riders_save_csv()
        self.scrape_stage_types()
        self.stage_types_save_csv()
    
    def scrape_stage_types(self):
        
        df_years = []
        df_stage = []
        df_type = []
        
        for year in self.years:
            site = "https://www.procyclingstats.com/race/tour-de-france/" + str(year) + "/gc/stages"
            target = Request(site, headers = self.hdr)
            target_page = urlopen(target)
            soup = BeautifulSoup(target_page)

            # check if page exists.
            if soup.find_all("div", {"class": "confirmation red notfound"}):
                print(site + " not found")
                continue

            target = Request(site, headers = self.hdr)
            target_page = urlopen(target)
            soup = BeautifulSoup(target_page)
            a = soup.find_all("div", {"class": "w2"})
            a = a[1:]
            a = [str(a[i]).split("icon profile ")[1].split('"')[0] for i,j in enumerate(a)]
            df_type.extend(a)
            df_years.extend([str(year) for i in range(len(a))])
            df_stage.extend([i + 1 for i in range(len(a))])
            
        data = {"year": df_years, "type": df_type, "stage": df_stage}
        
        self.df_stage_types = pd.DataFrame(data)

    def scrape_riders(self, start = 0):
        
        riders = [rider for rider in self.df_stages.Rider.unique()]
        riders_split = [str(rider).split() for rider in riders[start:]]
        
        df_first_names = []
        df_last_names = []
        df_nationality = []
        df_dates_of_birth = []
        df_heights = []
        df_weights = []
        df_one_day_races = []
        df_GC = []
        df_time_trial = []
        df_sprint = []
        df_climber = []
        
        for i, rider in enumerate(riders_split):
            
            # check for NAs
            if len(rider) < 2:
                continue
                
            first_name = rider[1].translate(self.dictionariy)
            second_name = rider[0].translate(self.dictionariy)

            if first_name in df_first_names:
                continue

            site = "https://www.procyclingstats.com/rider/" + first_name + "-" + second_name
            print(first_name, second_name)
            #print(site)
            target = Request(site,headers = self.hdr)
            target_page = urlopen(target)
            soup = BeautifulSoup(target_page)

            if soup.find_all("div", {"class": "confirmation red notfound"}):
                continue

            string = soup.find("div", {"class": "rdr-info-cont"})
            date_of_birth = string.get_text().split("Date of birth:")[1].split("(")[0]
            nationality = string.get_text().split("Nationality:")[1].split("Weight")[0]
            
            if "Height" in string.get_text():
                height = string.get_text().split("Height: ")[1].split("m")[0]
            else:
                height = "NA"
                
            if "Weight" in string.get_text():
                weight = string.get_text().split("Weight: ")[1].split("kg")[0]
            else:
                weight = "NA"
                
            one_day_races = string.get_text().split("Points per specialty")[1].split("A-Z")[0]#.split("[A-Za-z]")[0]
            one_day_races = re.split('[A-Z]', one_day_races)[0]
            GC = string.get_text().split("One day races")[1].split("A-Z")[0]#.split("[A-Za-z]")[0]
            GC = re.split('[A-Z]', GC)[0]
            time_trial = string.get_text().split("GC")[1].split("A-Z")[0]#.split("[A-Za-z]")[0]
            time_trial = re.split('[A-Z]', time_trial)[0]
            sprint = string.get_text().split("Time trial")[1].split("A-Z")[0]#.split("[A-Za-z]")[0]
            sprint = re.split('[A-Z]', sprint)[0]
            climber = string.get_text().split("Sprint")[1].split("A-Z")[0]#.split("[A-Za-z]")[0]
            climber = re.split('[A-Z]', climber)[0]

            df_first_names.append(rider[1])
            df_last_names.append(rider[0])
            df_nationality.append(nationality)
            df_dates_of_birth.append(date_of_birth)
            df_heights.append(height)
            df_weights.append(weight)
            df_one_day_races.append(one_day_races)
            df_GC.append(GC)
            df_time_trial.append(time_trial)
            df_sprint.append(sprint)
            df_climber.append(climber)

        data = {"First Name": df_first_names, "Last Names": df_last_names,
                "Nationality":df_nationality, "Dates of Birth": df_dates_of_birth, 
               "Height":df_heights, "Weight":df_weights, "One day races":df_one_day_races,
               "GC": df_GC, "Time trial":df_time_trial, "Sprint":df_sprint, "Climber":df_climber}

        self.df_riders = pd.DataFrame(data)
        
    def concat_df(self):
        
        if self.df_stages:
            self.df_stages = pd.concat(self.df_stages, sort = False)
        else:
            raise Exception("Dataframe empty.")
    
    def clean_riders(self):
        
        if not self.df_stages.empty:
            self.df_stages = self.df_stages.fillna(' ')
            self.df_stages['Rider'] = [re.sub(self.df_stages.iloc[i]['Team'], '', self.df_stages.iloc[i]['Rider']) if not isinstance(self.df_stages.iloc[i]['Rider'], float) else "NA" for i,j in enumerate(self.df_stages['Rider'])]
        else:
            raise Exception("Dataframe empty.")
    
    def stages_save_csv(self):

        if not self.df_stages.empty:
            self.df_stages.to_csv(self.name + "_stages.csv")
        else:
            raise Exception("Dataframe empty.")
            
    def riders_save_csv(self):

        if not self.df_riders.empty:
            self.df_riders.to_csv(self.name + "_riders.csv")
        else:
            raise Exception("Dataframe empty.")
            
    def stage_types_save_csv(self):

        if not self.df_stage_types.empty:
            self.df_stage_types.to_csv(self.name + "_stage_types.csv")
        else:
            raise Exception("Dataframe empty.")

# %%
tour = Scraper()
tour.scrape()
# Out:
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1903/stage-7 not found
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1904/stage-7 not found
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1905/stage-12 not found
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1906/stage-14 not found
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1907/stage-15 not found
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1908/stage-15 not found
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1909/stage-15 not found
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1910/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1911/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1912/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1913/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1914/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1915 not found
# https://www.procyclingstats.com/race/tour-de-france/1916 not found
# https://www.procyclingstats.com/race/tour-de-france/1917 not found
# https://www.procyclingstats.com/race/tour-de-france/1918 not found
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1919/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1920/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1921/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1922/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1923/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1924/stage-16 not found
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1925/stage-19 not found
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1926/stage-18 not found
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1927/stage-24
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1928/stage-23 not found
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1929/stage-23 not found
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1930/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1931/stage-24
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1932/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-24
# https://www.procyclingstats.com/race/tour-de-france/1933/stage-24 not found
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1934/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/1935/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1935/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1935/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1935/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1935/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1935/stage-5 not found
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1936/stage-13 not found
# https://www.procyclingstats.com/race/tour-de-france/1937/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1937/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1937/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1937/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1937/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1937/stage-5 not found
# https://www.procyclingstats.com/race/tour-de-france/1938/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1938/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1938/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1938/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1938/stage-4 not found
# https://www.procyclingstats.com/race/tour-de-france/1939/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1939/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1939/stage-2 not found
# https://www.procyclingstats.com/race/tour-de-france/1940 not found
# https://www.procyclingstats.com/race/tour-de-france/1941 not found
# https://www.procyclingstats.com/race/tour-de-france/1942 not found
# https://www.procyclingstats.com/race/tour-de-france/1943 not found
# https://www.procyclingstats.com/race/tour-de-france/1944 not found
# https://www.procyclingstats.com/race/tour-de-france/1945 not found
# https://www.procyclingstats.com/race/tour-de-france/1946 not found
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1947/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1948/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1949/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1950/stage-23 not found
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1951/stage-24
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-24
# https://www.procyclingstats.com/race/tour-de-france/1952/stage-24 not found
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-5
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-6
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-7
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-8
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-9
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-10
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-11
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-12
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-13
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-14
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-15
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-16
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-17
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-18
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-19
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-20
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-21
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-22
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-23
# https://www.procyclingstats.com/race/tour-de-france/1953/stage-23 not found
# https://www.procyclingstats.com/race/tour-de-france/1954/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1954/stage-2
# https://www.procyclingstats.com/race/tour-de-france/1954/stage-3
# https://www.procyclingstats.com/race/tour-de-france/1954/stage-4
# https://www.procyclingstats.com/race/tour-de-france/1954/stage-4 not found
# https://www.procyclingstats.com/race/tour-de-france/1955/stage-1
# https://www.procyclingstats.com/race/tour-de-france/1955/stage-1 not found
# https://www.procyclingstats.com/race/tour-de-france/1956/stage-1
# ...
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2002/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2003/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2004/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-22
# https://www.procyclingstats.com/race/tour-de-france/2005/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2006/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2007/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-22
# https://www.procyclingstats.com/race/tour-de-france/2008/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-22
# https://www.procyclingstats.com/race/tour-de-france/2009/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2010/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-22
# https://www.procyclingstats.com/race/tour-de-france/2011/stage-22 not found
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-8
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-9
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-10
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-11
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-12
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-13
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-14
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-15
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-16
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-17
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-18
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-19
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-20
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-21
# https://www.procyclingstats.com/race/tour-de-france/2012/stage-21 not found
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-1
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-2
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-3
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-4
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-5
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-6
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-7
# https://www.procyclingstats.com/race/tour-de-france/2013/stage-8
